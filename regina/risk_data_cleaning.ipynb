# %% [markdown]
# ##  Import and examine data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import os
# os.path.abspath("/Users/regi/Flatiron/mod4_project/data/RISKFACTORSANDACCESSTOCARE.csv")

# %%
risk_df = pd.read_csv('/Users/regi/Flatiron/mod4_project/data/RISKFACTORSANDACCESSTOCARE.csv')

# %%
risk_df.head(3)
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  No_Exercise  CI_Min_No_Exercise  \
# 0              AL                29         27.8                20.7
# 1              AL                16         27.2                23.2
# 2              AL                51      -1111.1             -1111.1
#
#    CI_Max_No_Exercise  Few_Fruit_Veg  ...  Diabetes  CI_Min_Diabetes  \
# 0                34.9           78.6  ...      14.2              9.1
# 1                31.2           76.2  ...       7.2              5.2
# 2             -1111.1        -1111.1  ...       6.6              2.0
#
#    CI_Max_Diabetes  Uninsured  Elderly_Medicare  Disabled_Medicare  \
# ...

# %%
risk_df.shape
# Out:
# (3141, 31)

# %%
risk_df.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number', 'No_Exercise',
#        'CI_Min_No_Exercise', 'CI_Max_No_Exercise', 'Few_Fruit_Veg',
#        'CI_Min_Fruit_Veg', 'CI_Max_Fruit_Veg', 'Obesity', 'CI_Min_Obesity',
#        'CI_Max_Obesity', 'High_Blood_Pres', 'CI_Min_High_Blood_Pres',
#        'CI_Max_High_Blood_Pres', 'Smoker', 'CI_Min_Smoker', 'CI_Max_Smoker',
#        'Diabetes', 'CI_Min_Diabetes', 'CI_Max_Diabetes', 'Uninsured',
#        'Elderly_Medicare', 'Disabled_Medicare', 'Prim_Care_Phys_Rate',
#        'Dentist_Rate', 'Community_Health_Center_Ind', 'HPSA_Ind'],
#       dtype='object')

# %%
risk_df = risk_df[risk_df.columns.drop(list(risk_df.filter(regex='Max')))]
risk_df = risk_df[risk_df.columns.drop(list(risk_df.filter(regex='Min')))]

# %%
risk_df.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number', 'No_Exercise',
#        'Few_Fruit_Veg', 'Obesity', 'High_Blood_Pres', 'Smoker', 'Diabetes',
#        'Uninsured', 'Elderly_Medicare', 'Disabled_Medicare',
#        'Prim_Care_Phys_Rate', 'Dentist_Rate', 'Community_Health_Center_Ind',
#        'HPSA_Ind'],
#       dtype='object')

# %%
risk_df.shape
# Out:
# (3141, 19)

# %%
risk_df.head(10)
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
# 5                1                11          Bullock         Alabama
# 6                1                13           Butler         Alabama
# 7                1                15          Calhoun         Alabama
# 8                1                17         Chambers         Alabama
# 9                1                19         Cherokee         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  No_Exercise  Few_Fruit_Veg  Obesity  \
# 0              AL                29         27.8           78.6     24.5
# ...

# %%
round(risk_df.describe(), 2)
# Out:
#        State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  No_Exercise  \
# count          3141.00           3141.00           3141.00      3141.00
# mean             30.30            103.72             44.70      -312.13
# std              15.13            108.00             25.12       520.27
# min               1.00              1.00              1.00     -1111.10
# 25%              18.00             35.00             23.00     -1111.10
# 50%              29.00             79.00             44.00        22.60
# 75%              45.00            133.00             66.00        28.60
# max              56.00            840.00             88.00        52.40
#
#        Few_Fruit_Veg  Obesity  High_Blood_Pres   Smoker  Diabetes   Uninsured  \
# count        3141.00  3141.00          3141.00  3141.00   3141.00     3141.00
# mean         -389.74  -307.28          -559.87  -292.49   -142.52    12644.81
# std           581.55   516.25           568.62   508.39    381.65    54604.78
# ...

# %%
(risk_df['No_Exercise'] == -1111.10).sum()
# Out:
# 935

# %%
# round(risk_df['Uninsured'].loc[risk_df['Uninsured'] != -2222].describe(), 2)

# %%
# risk_df['Uninsured'].loc[risk_df['Uninsured'] != -2222].value_counts()

# %%
for col in risk_df.columns:
    print(col)
    print(risk_df[col].value_counts())
    print('-------------------------')
# Out:
# State_FIPS_Code
# 48    254
# 13    159
# 51    134
# 21    120
# 29    115
# 20    105
# 17    102
# 37    100
# 19     99
# 47     95
# 31     93
# 18     92
# 39     88
# 27     87
# 26     83
# 28     82
# 40     77
# 5      75
# 55     72
# 42     67
# 1      67
# 12     67
# 46     66
# 8      64
# 22     64
# 36     62
# 6      58
# 30     56
# 54     55
# 38     53
# 45     46
# 16     44
# 53     39
# 41     36
# 35     33
# 49     29
# 2      27
# 24     24
# 56     23
# 34     21
# 32     17
# 23     16
# 4      15
# 50     14
# 25     14
# 33     10
# 9       8
# 44      5
# 15      5
# 10      3
# 11      1
# Name: State_FIPS_Code, dtype: int64
# -------------------------
# County_FIPS_Code
# 1      49
# 3      49
# 5      49
# 9      48
# 7      47
#        ..
# 381     1
# 379     1
# 377     1
# 375     1
# 6       1
# Name: County_FIPS_Code, Length: 324, dtype: int64
# -------------------------
# CHSI_County_Name
# Washington     32
# Jefferson      26
# ...

# %%
# NEW
# columns with placeholder values (-1111.1)
miss_data_1 = ['No_Exercise', 'Few_Fruit_Veg', 'Obesity', 'High_Blood_Pres', 'Smoker', 'Diabetes']
# columns with placeholder values (-2222.00)
miss_data_2 = ['Uninsured']
# columns we dont need
drop_cols = ['Community_Health_Center_Ind', 'HPSA_Ind', 'Elderly_Medicare', 'Disabled_Medicare', 'Prim_Care_Phys_Rate', 'Dentist_Rate']

# %% [markdown]
# ### Replace missing values with mean values by state and drop some cols

# %%
risk_df.drop(columns=drop_cols, inplace=True)

# %%
test_df = risk_df.copy(deep=True)

# %%
miss_cols = ['No_Exercise', 'Few_Fruit_Veg', 'Obesity', 'High_Blood_Pres', 'Smoker', 'Diabetes']

# %%
for col in miss_cols:
    test_df[col] = test_df[col].apply(lambda x: None if x == -1111.1 else x)

# %%
test_df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  No_Exercise  Few_Fruit_Veg  Obesity  \
# 0              AL                29         27.8           78.6     24.5
# 1              AL                16         27.2           76.2     23.6
# 2              AL                51          NaN            NaN     25.6
# 3              AL                42          NaN           86.6      NaN
# 4              AL                28         33.5           74.6     24.2
#
#    High_Blood_Pres  Smoker  Diabetes  Uninsured
# 0             29.1    26.6      14.2       5690
# ...

# %%
# dropped_df = pd.DataFrame()

# for col in miss_data_1:
#     dropped_df[col] = risk_df[col].loc[(risk_df[col] != -1111.1)]
# dropped_df.shape

# %%
data_gby_bad = risk_df.groupby('CHSI_State_Abbr').mean()

# %%
data_gby_bad
# Out:
#                  State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  \
# CHSI_State_Abbr
# AK                           2.0        154.148148         72.481481
# AL                           1.0         67.000000         40.970149
# AR                           5.0         75.000000         53.240000
# AZ                           4.0         13.866667         34.200000
# CA                           6.0         58.000000         20.706897
# CO                           8.0         62.234375         56.343750
# CT                           9.0          8.000000          7.750000
# DC                          11.0          1.000000          3.000000
# DE                          10.0          3.000000         13.333333
# FL                          12.0         67.910448         27.522388
# GA                          13.0        161.490566         49.100629
# HI                          15.0          5.000000         15.000000
# ...

# %%
data_gby = test_df.groupby('CHSI_State_Abbr').mean()

# %%
data_gby
# Out:
#                  State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  \
# CHSI_State_Abbr
# AK                           2.0        154.148148         72.481481
# AL                           1.0         67.000000         40.970149
# AR                           5.0         75.000000         53.240000
# AZ                           4.0         13.866667         34.200000
# CA                           6.0         58.000000         20.706897
# CO                           8.0         62.234375         56.343750
# CT                           9.0          8.000000          7.750000
# DC                          11.0          1.000000          3.000000
# DE                          10.0          3.000000         13.333333
# FL                          12.0         67.910448         27.522388
# GA                          13.0        161.490566         49.100629
# HI                          15.0          5.000000         15.000000
# ...

# %%
states = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
       'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
       'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
       'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
       'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
data_gby = test_df.groupby('CHSI_State_Abbr').mean()
data_gby.loc['AK','Diabetes']
# Out:
# nan

# %%
len(test_df[test_df['CHSI_State_Abbr'] == 'AK'])
# Out:
# 27

# %%
df.drop(df[df.score < 50].index, inplace=True)
[]

# %%
risk_df = risk_df[risk_df['CHSI_State_Abbr'] != 'AK']

# %%
risk_df.shape
# Out:
# (3114, 13)

# %%
# print(risk_df.index.values)
# print(len(risk_df.index.values))
# risk_df.index.values[5]

# %%
# risk_df.loc[3,'CHSI_State_Abbr']

# %%
# Replace the missing values with state-grouped means
def replace_with_state_mean(df, col_list, value):
    for col in col_list:
        miss_count = df[col].loc[(df[col] == value)].count()
        for ind in df.index.values:
            if df.loc[ind, col] == value:
                old_val = df.loc[ind, col]
                state = df.loc[ind, 'CHSI_State_Abbr']
                county = df.loc[ind, 'CHSI_County_Name']
                df.loc[ind, col] = data_gby.loc[state, col]
                print(f'Replacedold value of {old_val} for {col} for county {county} in state {state} with {data_gby.loc[state, col]} state mean')
            else: 
                continue
        print(f'Replaced {miss_count} values of {value} in {col} with state mean')

# %%
risk_df.No_Exercise.value_counts()
# Out:
# -1111.1    908
#  26.7       20
#  28.6       19
#  23.7       19
#  27.9       19
#           ...
#  44.8        1
#  42.0        1
#  43.9        1
#  10.3        1
#  38.7        1
# Name: No_Exercise, Length: 331, dtype: int64

# %%
replace_with_state_mean(risk_df, miss_data_1, -1111.1)
# Out:
# Replacedold value of -1111.1 for No_Exercise for county Barbour in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Bibb in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Bullock in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Cherokee in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Choctaw in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Clay in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Cleburne in state AL with 29.794999999999995 state mean
# Replacedold value of -1111.1 for No_Exercise for county Conecuh in state AL with 29.794999999999995 state mean
# ...

# %%
# risk_df.groupby(by='CHSI_State_Abbr').aggregate(mean)

# %%
risk_df.shape
# Out:
# (3114, 13)

# %%
round(risk_df.describe(), 2)

# %%
risk_df.head()

# %%
risks = risk_df.to_csv(‘/Users/regi/Flatiron/mod4_project/cleaned_data/cleaned_risk_factors.csv’,index=False)

# %%
risk_df.isna().sum()
# Out:
# State_FIPS_Code     0
# County_FIPS_Code    0
# CHSI_County_Name    0
# CHSI_State_Name     0
# CHSI_State_Abbr     0
# Strata_ID_Number    0
# No_Exercise         0
# Few_Fruit_Veg       0
# Obesity             0
# High_Blood_Pres     0
# Smoker              0
# Diabetes            0
# Uninsured           0
# dtype: int64

# %%
cleaned_risk = risk_df.to_csv('/Users/regi/Flatiron/mod4_project/cleaned_data/final_risk.csv',index=False)
